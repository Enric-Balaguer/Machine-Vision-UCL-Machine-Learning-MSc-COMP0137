# %% [markdown]
# # practicalMixGaussB
#
# The goal of this part of the lab is to fit a mixture of gaussians model to some one-dimensional data. To do this, we will first generate some data from a known mixture of gaussians model and fit our own mixture of gaussians model to the generated data. The parameters from our estimated mixture of gaussians model should roughly match those of the original known model.
#
# You should use this template for your code and fill in the missing
# sections marked "TO DO."
#
# PLEASE NOTE (again): You should NOT be using functions like multivariate_normal.pdf and normfit or any other numpy functions for fitting your distributions in this or further parts of this practical. Optionally, you can try comparing your results to those produced by those functions, but our goal here is to learn what is happening!

# %%
import os 
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as spio
from scipy.stats import norm 
import time

# %matplotlib inline

# %% [markdown]
# ## Construct Ground Truth Mixture of Gaussians Model and Plot Some Points
#
# Define some true parameters for our ground truth mixture of $k$ Gaussians model. We will represent the mixtures of Gaussians as a python dictionary. Note that we are working in one dimension, but if we were to require $d$ dimenisions, the mean field would be a $d \times k$ matrix and the cov field would be a $d \times d \times k$ matrix.

# %%
mixGaussTrue = dict()
mixGaussTrue['k'] = 2 # number of gaussians
mixGaussTrue['d'] = 1 # dimension of the data
mixGaussTrue['weight'] = np.array([0.3, 0.7]) # weight assigned to each gaussian
mixGaussTrue['mean'] = np.array([[-1,1.5]]) # the mean for each gaussian 
mixGaussTrue['cov'] = np.reshape([0.5, 0.25], newshape=(1,1,2)) # the covariance for each gaussian

# %% [markdown]
# **getGaussProb**, **sampleFromDiscrete**, and **drawEMData1d** are helper functions.

# %%
# subroutine to return gaussian probabilities
def getGaussProb(x,mean,var):   
    """
    Returns the likelihood that each data point in x belongs to the Gaussian described by mean and 
    var.
    
    Keyword arguments:
    x -- 1 by n vector of data points. n is the number of data points.
    mean -- scalar containing the mean parameter of the Gaussian distribution.
    var -- scalar containing the variance parameter of the Gaussian distribution.
    
    Returns: 
    prob -- scalar contianing the likelihood that each data point in data belongs to the Gaussian 
    distribution defined by mean and var.
    """
    mean = np.squeeze(mean)                                        
    var = np.squeeze(var)                                          
    prob = np.exp(-0.5*((x-mean)**2)/(var))                        
    prob = prob/ np.sqrt(2*np.pi*var)                              
    return prob

# %%
def sampleFromDiscrete(probDist): 
    """
    Draws a random sample from a discrete probability distribution using a rejection sampling method.  
    
    Keyword arguments:
    probDist -- discrete probability ditrubtion to sample from.
    
    Returns: 
    r -- sampled point.
    """

    nIndex = len(probDist)                                                                 
    while True:                                                                            
        #choose random index                                                               
        r=int(np.floor(np.random.uniform()*nIndex))                                        
        #choose random height                                                              
        randHeight = np.random.uniform()                                                   
        #if height is less than probability value at this point in the                     
        # histogram then select                                                            
        if randHeight<probDist[r]:                                                         
            break                                                                          
    return r

# %%
def drawEMData1d(data, mixGauss):
    """
    Draw the data, data, in histogram form and plot the mixtures of Gaussian model, mixGauss, on top of it.
    
    Keyword arguments:
    data -- 1 by n vector of data points.
    mixGauss -- dict with mixture of gaussian information.

    """
    # delete previous plot if it exists                                                                   
    # hold off;                                                                                           
    # bin the data to make a histogram                                                                    
                                                                                                          
    binWidth = 0.1;                                                                                       
    binMin = -4.0;                                                                                        
    binMax = 4.0;                                                                                         
    nSteps = int(np.ceil((binMax - binMin) / binWidth))                                                   
                                                                                                          
    nDims, nData = data.shape                                                                             
                                                                                                          
    xHist = np.linspace(binMin, binMax, nSteps, endpoint=True)                                            
    xHistExt = np.append(xHist, np.inf)                                                                   
    yHist, _ = np.histogram(data, xHistExt)                                     
                                                                                                          
    yHist = yHist / (nData * binWidth)                                                                    
    plt.cla()                                                                                     
    plt.bar(xHist, yHist, binWidth, edgecolor='b')                                                        
                                                                                                          
    # calculate Gaussian data                                                                             
    nGauss = mixGauss['k']                                                                                
    gaussEnvEst = np.zeros(xHist.shape)                                                                   
    for cGauss in range(nGauss):                                                                          
        # calculate weighted Gaussian values                                                              
        gaussProb = mixGauss['weight'][cGauss] * getGaussProb(xHist, mixGauss['mean'][:,cGauss],          
                                                              mixGauss['cov'][:, :, cGauss])              
        plt.plot(xHist, gaussProb, 'm-')  # weighted components of MoG                                    
        # add to form envelope                                                                            
        gaussEnvEst = gaussEnvEst + gaussProb                                                             
                                                                                                          
    plt.plot(xHist, gaussEnvEst, 'g-')  # final mixture of Gaussians                                      
                                                                                                          
    # tidy up plot                                                                                        
    plt.xlabel('Data Value')                                                                              
    plt.ylabel('Probability Density')                                                                     
    # set(gca,'Box','Off');                                                                               
    # set(gcf,'Color',[1 1 1]);                                                                           
    plt.xlim((binMin, binMax))                                                                            
    plt.ylim((0, max(yHist) * 1.5))                                                                       
                                                                                                          
    return

# %% [markdown]
# **TODO HERE:**
#
# Complete the TO DO in this function before moving on.

# %%
def mixGaussGen1d(mixGauss, nData):  
    """
    Generates data from a one-dimensional mixture of Gaussians model. 
    
    Keyword arguments:
    mixGauss -- dict containing the mixture of gaussians arguments.
    nData -- number of data points to generate.
    
    Returns: 
    data -- 1 by nData, generated data points. 
    """
    
    # create space for output data                                                                               
    data = np.zeros(shape=(1, nData))                                                                            
    # for each data point                                                                                        
    for cData in range(nData):                                                                                   
        # randomly choose Gaussian according to probability distributions                                        
        h = sampleFromDiscrete(mixGauss['weight'])  #h is either a 0 or 1                                                       
        # draw a sample from the appropriate Gaussian distribution                                               
        mean = mixGauss["mean"][:,h]
        cov_matrix = mixGauss["cov"][:,:,h]

        data[:, cData] = np.random.normal(mean,(cov_matrix)**(1/2)) #data is a n vector

    return data

# %% [markdown]
# With all the helper functions complete, we can now generate and plot some points from our model. The blue bars are the histogram of the generated points. The green curve is what the complete mixture of gaussians model looks like. The pink curves are the component gaussians.

# %%
# define number of samples to generate
nData = 400

#generate data from the mixture of Gaussians
#make sure you've filled out the todo above! 
data = mixGaussGen1d(mixGaussTrue,nData)

#plot! 
fig,ax = plt.subplots(1,1)
drawEMData1d(data,mixGaussTrue)

# %% [markdown]
# The plot above shows a mixture of 2, 1-dimensional gaussians. The purple lines show each 1-dimensional gaussian and the green line shows the ground truth mixture of 2, 1-dimensional gaussians.
# \
# \
# From such probability distribution, we sample 400 data points out of it, as shown in the blue histogram.

# %% [markdown]
# ## Estimate MoG using the E-M Algorithm
# Here we want to use the E-M algorithm to fit a MoG model to our data points.
#
# **TODO HERE:**
#
# Fill out the missing parts below.

# %%
def getMixGaussBound(data, mixGaussEst, responsibilities):                                                  
    """
    Calculate the bound on the log likelihood for the whole data set under a mixture of Gaussians model.  
    
    Keyword arguments:
    data -- d by n matrix containing data points. #I think d == 1
    mixGaussEst -- dict containing the mixture of gaussians parameters.
    responsibilities -- k by n vector containing the responsibility of this data point for each Gaussian. 
    
    Returns: 
    bound -- scalar containing the bound on the log likelihood.
    
    """
    # find total number of data items                                                                       
    nDims, nData = data.shape                                                                               
                                                                                                            
    # initialize bound                                                                                      
    bound = 0                                                                                               
    # run through each data item                                                                            
    for cData in range(nData):  #Running til n                                                                             
        # extract this data                                                                                 
        thisData = data[:, cData]                                                                              
        # extract this q(h)                                                                                 
        thisQ = responsibilities[:, cData] # ThisQ is a k*1 vector, the different responsibilities for cData                                                                  
                                                                                                            
        # TO DO - calculate contribution to bound of this datapoint                                         
        # Replace this
        boundValue = 0
        for k_1 in range(mixGaussEst["k"]):
            
            mean = mixGaussEst["mean"][:,k_1]            #mean for k-th Gaussian
            cov = mixGaussEst["cov"][:,:,k_1]           #cov for k-th Gaussian SHOULD I SQUARE IT?
            k_gamma = mixGaussEst["weight"][k_1]          #k-th gamma (weight) for the k-th Gaussian
            #Make everything above for multivariate gaussian such that thisData below gets vector as entry. to do in C
            boundValue = thisQ[k_1] * np.log((k_gamma*getGaussProb(thisData, mean, cov)) / thisQ[k_1])

            # add to total log like                                                                             
            bound = bound + boundValue                                                                     
                                                                                                            
    return np.array(bound).item()

# %% [markdown]
# **TODO HERE:**
#
# Fill out the missing parts below.
#
# The log likelihood is taken since the raw likelihood value could be too small for our machine's percision.

# %%
def getMixGaussLogLike(data, mixGaussEst):
    """
    Calculate the log likelihood for the whole dataset under a mixture of Gaussians model.
    
    Keyword arguments:
    data -- d by n matrix containing data points.
    mixGaussEst -- dict containing the mixture of gaussians parameters.

    Returns: 
    logLike -- scalar containing the log likelihood.
    
    """
    data = np.atleast_2d(data)                                                                         
    # find total number of data items                                                                  
    nDims, nData = data.shape                                                                          
    
    # initialize log likelihoods                                                                       
    logLike = 0                                                                                       
                                                                                                       
    # run through each data item                                                                       
    for cData in range(nData):                                                                         
        thisData = data[:, cData]   #thisData is a potential d vector
        like = 0
        for k_1 in range(mixGaussEst["k"]):
            mean = mixGaussEst["mean"][:,k_1]            #mean for k-th Gaussian
            cov = mixGaussEst["cov"][:,:,k_1]           #cov for k-th Gaussian
            k_gamma = mixGaussEst["weight"][k_1]          #k-th gamma (weight) for the k-th Gaussian
                
            like += k_gamma * getGaussProb(thisData, mean, cov)
                                                                                                       
        # add to total log like                                                                        
        logLike = logLike + np.log(like)                                                               
                                                                                                       
    return  np.array(logLike).item()
# Out:
# '     data = np.atleast_2d(data)\n    \n    # find total number of data items                                                                  \n    nDims, nData = data.shape                                                                          \n    \n    # initialize log likelihoods                                                                       \n    logLike = 0\n                                                                                                       \n    # run through each data item                                                                       \n    for cData in range(nData):                                                                         \n        thisData = data[:, cData]\n\n        like = []\n        for k_1 in range(mixGaussEst["k"]):\n            #gamma_k as shown in cribsheet\n            gamma_k = mixGaussEst["weight"][k_1]\n            #Probability of d-dimensional data to have been generated from k-th multivariate gaussian\n            constant_term = (2*np.pi)**(-0.5*mixGaussEst["d"])\n            add_det_term = constant_term * (np.linalg.det(mixGaussEst["cov"][:,:,k_1])**(-0.5))\n            difference_vector = thisData - mixGaussEst["mean"][:,k_1]\n            exp_term = np.exp(-0.5*(np.transpose(difference_vector) @ np.linalg.inv(mixGaussEst["cov"][:,:,k_1]) @ difference_vector))\n            prob = add_det_term * exp_term\n            #Add the log of the multiplication of both terms\n            like.append(gamma_k*prob)\n\n        like = np.array(like)\n        logLike += np.log(np.sum(like))\n\n    return  logLike '

# %% [markdown]
# **TODO HERE:**
#
# Fill out the missing parts below.

# %%
def fitMixGauss1d(data, k):   
    """
    Estimate a k MoG model that would fit the data. Incremently plots the outcome.
               
    
    Keyword arguments:
    data -- d by n matrix containing data points.
    k -- scalar representing the number of gaussians to use in the MoG model.
    
    Returns: 
    mixGaussEst -- dict containing the estimated MoG parameters.
    
    """
    #     MAIN E-M ROUTINE  
    #     In the E-M algorithm, we calculate a complete posterior distribution over                                  
    #     the (nData) hidden variables in the E-Step.  
    #     In the M-Step, we update the parameters of the Gaussians (mean, cov, w).   
    
    nDims, nData = data.shape      

    responsibilities = np.zeros(shape=(k, nData))                                                                                                                                                      
                                                                                                                     
    # we will initialize the values to random values                                                                 
    mixGaussEst = dict()                                                                                             
    mixGaussEst['d'] = 1                                                                                             
    mixGaussEst['k'] = k                                                                                             
    mixGaussEst['weight'] = (1 / k) * np.ones(shape=(k))                                                             
    mixGaussEst['mean'] = 2 * np.random.randn(1, k)                                                                  
    mixGaussEst['cov'] = 0.1 + 1.5*np.random.uniform(size=(1,1,2))                                                   
                                                                                                                     
    # calculate current likelihood                                                                                   
    # TO DO - fill in this routine                                                                                   
    logLike = getMixGaussLogLike(data, mixGaussEst)                                                                  
    print('Log Likelihood Iter 0 : {:4.3f}\n'.format(logLike))                                                       
                                                                                                                     
    nIter = 30                                                                                                   
                                                                                                                     
    logLikeVec = np.zeros(shape=(2 * nIter))                                                                         
    boundVec = np.zeros(shape=(2 * nIter)) 
    
    fig,ax = plt.subplots(1,1)
                                                                                                                     
    for cIter in range(nIter):                                                                                       
                                                                                                                     
        # ===================== =====================                                                                
        # Expectation step                                                                                           
        # ===================== =====================                                                                
        curCov = mixGaussEst['cov']                                                                                  
        curWeight = mixGaussEst['weight']                                                                            
        curMean = mixGaussEst['mean']  

        responsibilities = []
        for cData in range(nData):
            thisData = data[:, cData]
            l = []
            for k_1 in range(k):
                #Need to first calculate probability of each datapoint being in k1-th dist and multiply it for chance of being in that dist
                #gamma_k as shown in cribsheet
                gamma_k = mixGaussEst["weight"][k_1]
                #Probability of d-dimensional data to have been generated from k-th multivariate gaussian
                constant_term = (2*np.pi)**(-0.5*mixGaussEst["d"])
                add_det_term = constant_term * (np.linalg.det(mixGaussEst["cov"][:,:,k_1])**(-0.5))
                difference_vector = thisData - mixGaussEst["mean"][:,k_1]
                exp_term = np.exp(-0.5*(np.transpose(difference_vector) @ np.linalg.inv(mixGaussEst["cov"][:,:,k_1]) @ difference_vector))

                l.append(gamma_k*add_det_term * exp_term)

            l = np.array(l)
            #Need to normalise the responsibilities
            l = l/(np.sum(l))
            #Add it to responsibilities
            responsibilities.append(l)
            
        responsibilities = np.transpose(np.array(responsibilities))

        #Initial methods I deleted after completing practical C
        """l = np.zeros(mixGaussEst["k"])
        for k_1 in range(mixGaussEst["k"]):
            l[k_1] = curWeight[k_1] * getGaussProb(thisData, curMean[:,k_1], curCov[:,:,k_1])

        #Normalise it when adding it to responsibilities
        responsibilities[:,cData] = (l/np.sum(l)) """

        # calculate the log likelihood                                                                               
        logLike = getMixGaussLogLike(data, mixGaussEst)                                                              
        print('Log Likelihood After E-Step Iter {} : {:4.3f}\n'.format(cIter, logLike))                              
                                                                                                                     
        # calculate the bound                                                                                        
        # TO DO - Fill in this routine                                                                               
        bound = getMixGaussBound(data, mixGaussEst, responsibilities)                                                
        print('Bound After E-Step Iter {} : {:4.3f}\n'.format(cIter, bound))     
        
        logLikeVec[2 * cIter] = logLike                                                                              
        boundVec[2 * cIter] = bound                                                                                  
        # ===================== =====================                                                                
        # Maximization Step                                                                                          
        # ===================== =====================                                                                
        # for each constituent Gaussian                                                                              
        for cGauss in range(mixGaussEst["k"]):
            # I vectorise this part for simplicity. I got a lot of help from the cribsheet
            # Update weights                            
            mixGaussEst['weight'][cGauss] = np.sum(responsibilities[cGauss,:])/nData

            # Update means
            mixGaussEst['mean'][:,cGauss] = np.sum(responsibilities[cGauss,:]*data,axis=1)/np.sum(responsibilities[cGauss,:])

            # Update covariance
            diff = np.transpose(data)-mixGaussEst['mean'][:,cGauss]
            first = np.transpose(diff) * responsibilities[cGauss,:]
            second = first @ diff
            mixGaussEst['cov'][:,:,cGauss] = second/ np.sum(responsibilities[cGauss,:])
            #Initial methods I deleted after completing practical C
            """ diff = data-mixGaussEst['mean'][:,cGauss]
            nominator = np.sum(responsibilities[cGauss, :] * diff**2)
            mixGaussEst['cov'][:,:,cGauss] = nominator/ np.sum(responsibilities[cGauss,:]) """

                                                                                                         
        # draw the new solution  
        drawEMData1d(data, mixGaussEst)
        time.sleep(0.7)
        fig.canvas.draw()
                                                                                                                     
        # calculate the log likelihood                                                                               
        logLike = getMixGaussLogLike(data, mixGaussEst)                                                              
        print('Log Likelihood After M-Step Iter {} : {:4.3f}\n'.format(cIter, logLike))                              
                                                                                                                     
        # calculate the bound                                                                                        
        bound = getMixGaussBound(data, mixGaussEst, responsibilities)                                                
        print('Bound After M-Step Iter {} : {:4.3f}\n'.format(cIter, bound)) 
                                                                                                                  
        logLikeVec[2 * cIter + 1] = logLike                                                                          
        boundVec[2 * cIter + 1] = bound                                                                              
                                                                                                                     
    plt.figure()                                                                                                     
    plt.plot(logLikeVec, 'g',label='log likelihood')                                                                                        
    plt.plot(boundVec, 'r',label='lower bound')  
    plt.legend()
                                                                                                                     
    return mixGaussEst

# %% [markdown]
# ### Time to put it all together!
#
# Make sure you've filled all the TO DOs above!

# %%
#generate data from the ground truth mixture of Gaussians we've defined way above. 
#make sure you've completed this routine above.
data = mixGaussGen1d(mixGaussTrue,nData);

#draw data, ground truth mixture of Gaussians.
drawEMData1d(data,mixGaussTrue)

#define number of components to estimate
nGaussEst = 2;

#fit mixture of Gaussians (Pretend someone handed you some data. Now what?)
#Make sure you've completed this routine above.
mixGaussEst = fitMixGauss1d(data,nGaussEst);
# Out:
# Log Likelihood Iter 0 : -1998.479
#
# Log Likelihood After E-Step Iter 0 : -1998.479
#
# Bound After E-Step Iter 0 : -1998.479
#
# Log Likelihood After M-Step Iter 0 : -634.750
#
# Bound After M-Step Iter 0 : -645.308
#
# Log Likelihood After E-Step Iter 1 : -634.750
#
# Bound After E-Step Iter 1 : -634.750
#
# Log Likelihood After M-Step Iter 1 : -614.418
#
# Bound After M-Step Iter 1 : -622.567
#
# Log Likelihood After E-Step Iter 2 : -614.418
#
# Bound After E-Step Iter 2 : -614.418
#
# Log Likelihood After M-Step Iter 2 : -606.285
#
# Bound After M-Step Iter 2 : -608.914
#
# Log Likelihood After E-Step Iter 3 : -606.285
#
# Bound After E-Step Iter 3 : -606.285
#
# Log Likelihood After M-Step Iter 3 : -604.212
#
# Bound After M-Step Iter 3 : -604.927
#
# Log Likelihood After E-Step Iter 4 : -604.212
#
# Bound After E-Step Iter 4 : -604.212
#
# Log Likelihood After M-Step Iter 4 : -603.358
#
# Bound After M-Step Iter 4 : -603.735
#
# Log Likelihood After E-Step Iter 5 : -603.358
#
# Bound After E-Step Iter 5 : -603.358
#
# Log Likelihood After M-Step Iter 5 : -602.658
#
# Bound After M-Step Iter 5 : -603.004
#
# Log Likelihood After E-Step Iter 6 : -602.658
#
# Bound After E-Step Iter 6 : -602.658
#
# Log Likelihood After M-Step Iter 6 : -601.930
#
# Bound After M-Step Iter 6 : -602.298
#
# Log Likelihood After E-Step Iter 7 : -601.930
#
# Bound After E-Step Iter 7 : -601.930
#
# Log Likelihood After M-Step Iter 7 : -601.130
#
# Bound After M-Step Iter 7 : -601.537
#
# Log Likelihood After E-Step Iter 8 : -601.130
#
# Bound After E-Step Iter 8 : -601.130
#
# Log Likelihood After M-Step Iter 8 : -600.234
#
# Bound After M-Step Iter 8 : -600.691
#
# Log Likelihood After E-Step Iter 9 : -600.234
#
# Bound After E-Step Iter 9 : -600.234
#
# Log Likelihood After M-Step Iter 9 : -599.219
#
# Bound After M-Step Iter 9 : -599.735
#
# Log Likelihood After E-Step Iter 10 : -599.219
#
# Bound After E-Step Iter 10 : -599.219
#
# Log Likelihood After M-Step Iter 10 : -598.066
#
# Bound After M-Step Iter 10 : -598.650
#
# Log Likelihood After E-Step Iter 11 : -598.066
#
# Bound After E-Step Iter 11 : -598.066
#
# Log Likelihood After M-Step Iter 11 : -596.772
#
# Bound After M-Step Iter 11 : -597.424
#
# Log Likelihood After E-Step Iter 12 : -596.772
#
# Bound After E-Step Iter 12 : -596.772
#
# Log Likelihood After M-Step Iter 12 : -595.353
#
# Bound After M-Step Iter 12 : -596.060
#
# Log Likelihood After E-Step Iter 13 : -595.353
#
# Bound After E-Step Iter 13 : -595.353
#
# Log Likelihood After M-Step Iter 13 : -593.858
#
# Bound After M-Step Iter 13 : -594.593
#
# Log Likelihood After E-Step Iter 14 : -593.858
#
# Bound After E-Step Iter 14 : -593.858
#
# Log Likelihood After M-Step Iter 14 : -592.369
#
# Bound After M-Step Iter 14 : -593.088
#
# Log Likelihood After E-Step Iter 15 : -592.369
#
# Bound After E-Step Iter 15 : -592.369
#
# Log Likelihood After M-Step Iter 15 : -590.998
#
# Bound After M-Step Iter 15 : -591.645
#
# Log Likelihood After E-Step Iter 16 : -590.998
#
# Bound After E-Step Iter 16 : -590.998
#
# Log Likelihood After M-Step Iter 16 : -589.855
#
# Bound After M-Step Iter 16 : -590.379
#
# Log Likelihood After E-Step Iter 17 : -589.855
#
# Bound After E-Step Iter 17 : -589.855
#
# Log Likelihood After M-Step Iter 17 : -589.014
#
# Bound After M-Step Iter 17 : -589.387
#
# Log Likelihood After E-Step Iter 18 : -589.014
#
# Bound After E-Step Iter 18 : -589.014
#
# Log Likelihood After M-Step Iter 18 : -588.475
#
# Bound After M-Step Iter 18 : -588.706
#
# Log Likelihood After E-Step Iter 19 : -588.475
#
# Bound After E-Step Iter 19 : -588.475
#
# Log Likelihood After M-Step Iter 19 : -588.173
#
# Bound After M-Step Iter 19 : -588.298
#
# Log Likelihood After E-Step Iter 20 : -588.173
#
# Bound After E-Step Iter 20 : -588.173
#
# Log Likelihood After M-Step Iter 20 : -588.024
#
# Bound After M-Step Iter 20 : -588.084
#
# Log Likelihood After E-Step Iter 21 : -588.024
#
# Bound After E-Step Iter 21 : -588.024
#
# Log Likelihood After M-Step Iter 21 : -587.956
#
# Bound After M-Step Iter 21 : -587.982
#
# Log Likelihood After E-Step Iter 22 : -587.956
#
# Bound After E-Step Iter 22 : -587.956
#
# Log Likelihood After M-Step Iter 22 : -587.927
#
# Bound After M-Step Iter 22 : -587.938
#
# Log Likelihood After E-Step Iter 23 : -587.927
#
# Bound After E-Step Iter 23 : -587.927
#
# Log Likelihood After M-Step Iter 23 : -587.915
#
# Bound After M-Step Iter 23 : -587.920
#
# Log Likelihood After E-Step Iter 24 : -587.915
#
# Bound After E-Step Iter 24 : -587.915
#
# Log Likelihood After M-Step Iter 24 : -587.910
#
# Bound After M-Step Iter 24 : -587.912
#
# Log Likelihood After E-Step Iter 25 : -587.910
#
# Bound After E-Step Iter 25 : -587.910
#
# Log Likelihood After M-Step Iter 25 : -587.908
#
# Bound After M-Step Iter 25 : -587.909
#
# Log Likelihood After E-Step Iter 26 : -587.908
#
# Bound After E-Step Iter 26 : -587.908
#
# Log Likelihood After M-Step Iter 26 : -587.908
#
# Bound After M-Step Iter 26 : -587.908
#
# Log Likelihood After E-Step Iter 27 : -587.908
#
# Bound After E-Step Iter 27 : -587.908
#
# Log Likelihood After M-Step Iter 27 : -587.907
#
# Bound After M-Step Iter 27 : -587.908
#
# Log Likelihood After E-Step Iter 28 : -587.907
#
# Bound After E-Step Iter 28 : -587.907
#
# Log Likelihood After M-Step Iter 28 : -587.907
#
# Bound After M-Step Iter 28 : -587.907
#
# Log Likelihood After E-Step Iter 29 : -587.907
#
# Bound After E-Step Iter 29 : -587.907
#
# Log Likelihood After M-Step Iter 29 : -587.907
#
# Bound After M-Step Iter 29 : -587.907

# %% [markdown]
# The first figure is the ground truth distribution (green line) the 400 samples histogram is sampled from, as explained above (first figure in practical).
# \
# \
# The second figure plots the same 400 samples shown in the blue histogram, with the mixture of guassians our EM algorithm fit to the provided data. We can see our EM algorithm did a great job plotting the two 1-dimensional gaussians to the provided data!
# \
# \
# This is further confirmed by the plot of the log likelihood vs EM iterations shown in the last graph. Our log likelihood gets maximised, never falls below the lower bound and converges to the desired result! For future improvements, I would make the EM algorithm stop iterating after change in likelihood is less than what we consider "small", to make the algorithm more efficient.
